# %% [markdown]
# # Pandas is a popular library of Python for Data Analysis and Data Visualization

# %%
# For importing Pandas
import pandas as pd

# %%
# Loading Dataset
import seaborn as sns
sns.get_dataset_names()
df=sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# Shape of the dataset
df.shape
# Out:
# (150, 5)

# %%
# Acessing the first five data points
df.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Acessing the last five data points
df.tail(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
# The column names of dataset
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
# Checking if any null value is present in the dataset
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
# for acessing any particular column
df['sepal_length']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
# Boolean Indexing
df[df['sepal_width']>=3.0]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 144           6.7          3.3           5.7          2.5  virginica
# 145           6.7          3.0           5.2          2.3  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [93 rows x 5 columns]

# %%
# Checking mathematical stats for numerical columns
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# Checking the data types of various columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# Grouping rows of several columns
df.groupby(['sepal_length','sepal_width','petal_length']).size()
# Out:
# sepal_length  sepal_width  petal_length
# 4.3           3.0          1.1             1
# 4.4           2.9          1.4             1
#               3.0          1.3             1
#               3.2          1.3             1
# 4.5           2.3          1.3             1
#                                           ..
# 7.7           2.6          6.9             1
#               2.8          6.7             1
#               3.0          6.1             1
#               3.8          6.7             1
# 7.9           3.8          6.4             1
# Length: 144, dtype: int64

# %%
# Deleting any column from the dataset
df_copy=df.copy()
df_copy.drop('petal_length',axis=1,inplace=True)
df_copy
# Out:
#      sepal_length  sepal_width  petal_width    species
# 0             5.1          3.5          0.2     setosa
# 1             4.9          3.0          0.2     setosa
# 2             4.7          3.2          0.2     setosa
# 3             4.6          3.1          0.2     setosa
# 4             5.0          3.6          0.2     setosa
# ..            ...          ...          ...        ...
# 145           6.7          3.0          2.3  virginica
# 146           6.3          2.5          1.9  virginica
# 147           6.5          3.0          2.0  virginica
# 148           6.2          3.4          2.3  virginica
# 149           5.9          3.0          1.8  virginica
#
# [150 rows x 4 columns]

# %% [markdown]
# ### For handling Nan values if present
# ### We have 2 functions
# ### df.fillna()
# ### df.dropna()

# %%
# Finding Corelation between columns
df.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %% [markdown]
# ### Other Important Functions in Pandas
#
#
# ### 1. Merging datasets pd.merge(df1,df2,on='',how='')
# ### 2. Appending datasets = df.append(df2)
# ### 3. Mapping some features in a column = df[column_name].map({})
# ### 4. Finding standard deviation = df.std()
# ### 5. Reading csv files = df.read_csv()
# ### 6. Reading sql queries=df.read_sql_query()
